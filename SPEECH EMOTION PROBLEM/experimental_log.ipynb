# %% [markdown]
# ## SPEECH EMOTION PROBLEM experimental_log

# %% [markdown]
# ### STEP 1: Audio to text conversion

# %% [markdown]
# #### A. Using speech_recognition module with recognize_google as Recognizer
# Total Audio Files in Disgust Folder : 232 <br>
# Total Audio Files converted to text : 69 <br>
# Since speech recognition technique cannot convert enough audio files to text, we cannot approach the problem with NLP

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### B. Using Spectrogram conversion on audio files
# Converting the audio files to spectrogram and then using image classifiation on the produced spectrograms

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# All audio files are converted to their respective spectrogram images and saved in the 'imgs' folder for every folder<br> using the main.py python script

# %% [markdown]
# ### Using cnn with a Stochastic gradient descent optimizer
# Very poor performance

# %% [markdown]
# ### Using CNN model with rmsprop as the optimizer with default learning rate
# Gives an accuracy of around 60%

# %% [markdown]
# ![Screenshot%20from%202019-10-22%2021-47-33.png](attachment:Screenshot%20from%202019-10-22%2021-47-33.png)

# %% [markdown]
# ### Using CNN model with rmsprop as the optimizer with learning rate 0.5
# From the loss value, evidently the learning rate is too high

# %% [markdown]
# ![Screenshot%20from%202019-10-30%2005-03-25.png](attachment:Screenshot%20from%202019-10-30%2005-03-25.png)
